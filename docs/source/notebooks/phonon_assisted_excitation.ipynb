# %% [markdown]
# # Phonon-assisted excitation

# %% [markdown]
# ## Table of contents
# - Theory background
# - Photoluminescence excitation
# - Lifetime
# - Photon statistics
# - Custom pulse shapes

# %% [markdown]
# ## 1. Theory background

# %% [markdown]
# The theory of phonon-assisted excitation is relatively complicated compared to other sources demonstrated in other example notebooks. Luckily, there are many great references that give clarity beyond what can be said in this brief section. An interested reader is invited to look at the following papers:
#
# 1) [J. H. Quilter et al., Phonon-Assisted Population Inversion of a Single InGaAs/GaAs Quantum Dot by Pulsed Laser Excitation, Phys. Rev. Lett. 114, 137401 (2015).](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.114.137401)
# 2) [A. M. Barth et al., Fast and selective phonon-assisted state preparation of a quantum dot by adiabatic undressing, Phys. Rev. B 94, 045306 (2016).](https://journals.aps.org/prb/abstract/10.1103/PhysRevB.94.045306)
# 3) [M. Cosacchi et al., Emission-Frequency Separated High Quality Single Photon Sources Enabled by Phonons, Phys. Rev. Lett. 123, 017403 (2019)](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.123.017403).
# 4) [C. Gustin and S. Hughes, Efficient pulse-excitation techniques for single photon sources from quantum dots in optical cavities, Adv. Quantum Technol. 3, 1900073 (2020)](https://onlinelibrary.wiley.com/doi/abs/10.1002/qute.201900073)
# 5) [S. E. Thomas et al., Bright Polarized Single-Photon Source Based on a Linear Dipole, Phys. Rev. Lett. 126, 233601 (2021).](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.126.233601)
#
# The catalogue phonon-assisted source model used in the ZPG package is based on the fourth reference [[C. Gustin and S. Hughes, Adv. Quantum Technol. 3, 1900073 (2020)](https://onlinelibrary.wiley.com/doi/abs/10.1002/qute.201900073)] and can be constructed using the Source.phonon_assisted() class method. The master equation of the form $\dot{\rho}(t)=\mathcal{L}(t)\hat{\rho}(t)$ that defines this source is given by
#
# \begin{equation}
#     \mathcal{L}(t) = \mathcal{L}_\mathrm{purcell}(t) + \mathcal{L}_\mathrm{ph.}(t)
# \end{equation}
# where $\mathcal{L}_\text{purcell}$ is the master equation defining the Source.purcell() catalogue source (see ex_cavityQED.ipynb). The phonon superoperator is defined as
#
# \begin{equation}
#     \mathcal{L}_\mathrm{ph.} = &-i\mathcal{H}_\mathrm{ph.}+\gamma^\star_\mathrm{ph.}\mathcal{D}_\hat{N}+(\Omega_y c_1-\Omega_x c_2)\hat{O}_x^++i(\Omega_y c_3-\Omega_x c_4)\hat{O}_x^--(\Omega_x c_1+\Omega_y c_2)\hat{O}_y^+-i(\Omega_x c_3+\Omega_y c_4)\mathcal{O}_y^-,
# \end{equation}
# where $\mathcal{H}_\mathrm{ph.}\hat{\rho}=-[\Delta_\mathrm{ph.},\hat{\rho}]$ is the polaron shift, $\hat{N}=\hat{\sigma}^\dagger\hat{\sigma}$, and $\mathcal{O}_i^\pm\hat{\rho} = \hat{\sigma}_i\hat{\rho}\hat{N} - \hat{N}\hat{\sigma}_i\hat{\rho} \pm \mathrm{H.c.}$, and where $\hat{\sigma}_i$ for $i\in\{x, y, z\}$ are the Pauli matrices. The Rabi frequencies $\Omega_x$ and $\Omega_y$, corresponding to the real and complex parts of the excitation pulse, are time dependent. In addition, the coefficients $c_i$ and the phonon-induced power-dependent pure dephasing rate $\gamma^\star_\mathrm{ph.}$ are also all time dependent and related to the phonon spectral density $J_\mathrm{ph.}(\omega)$ by
# \begin{equation}
# \begin{aligned}
# c_1 &= \frac{\mathrm{Re}(R_s)}{\Omega_R} \\
# c_2 &= \frac{\Delta_\sigma\mathrm{Re}(R_c)}{\Omega_R^2} \\
# c_3 &= \frac{\mathrm{Im}(R_s)}{\Omega_R} \\
# c_4 &= \frac{\Delta_\sigma}{\Omega_R^2} \left(\frac{\Delta_{\mathrm{p}}}{2} + \mathrm{Im}(R_c)\right)\\
# \gamma^\star_\mathrm{ph.} &=4\frac{\Omega_x^2+\Omega_y^2}{\Omega_R}\mathrm{Re}(R_c)
# \end{aligned}
# \end{equation}
# where $\Omega_R(t)=\sqrt{\Delta_\sigma^2 + \Omega_x^2(t) + \Omega_y^2(t)}$ is the effective Rabi frequency for a constant laser detuning of $-\Delta$,
# \begin{equation}
# \begin{aligned}
# R_s(t) &= \frac{1}{2}\int_0^\infty d\tau\Gamma(\tau)\sin(\Omega_R(t)\tau)\\
# R_c(t) &= \frac{1}{2}\int_0^\infty d\tau\Gamma(\tau)\cos(\Omega_R(t)\tau),
# \end{aligned}
# \end{equation}
# and
# \begin{equation}
# \Gamma(\tau) = \int_0^\infty d\omega J_{\mathrm{ph.}}(\omega)\left[\mathrm{coth}\left(\frac{\hbar\omega}{2k_BT}\right)\cos(\omega\tau)-i\sin(\omega\tau)\right].
# \end{equation}
# The polaron shift $\Delta_\mathrm{ph.}$ can also be expressed in terms of the rate $\Gamma(\tau)$ by
# \begin{equation}
# \Delta_\mathrm{ph.} = i\int_0^\infty d\tau \Gamma_\mathrm{ph.}(\tau)
# \end{equation}
#
# Overall, the parameters that impact this system are the same as the Source.purcell() source but with the additional option of specifying a phonon bath temperature and a material type. As of now there is only one material type that is based on an InGaAs/GaAs quantum dot.

# %% [markdown]
# ## 2. Photoluminescence excitation

# %%
from zpgenerator import *
import numpy as np
import matplotlib.pyplot as plt


def resonance_scan_parameters(detuning, parameters=None):
    return {
        'emitter/resonance': -detuning,
        'cavity/resonance': -detuning,
        **(parameters or {}),
    }

# %% [markdown]
# To test the phonon-assisted excitation scheme, we will use InGaAs/GaAs quantum dot at a temperature of 7 K with a modest Purcell enhancement of 10 from a cavity operating in the bad-cavity regime (0.1). Also, because the scheme can be sensitive to pulses with strange features, we will use a standard Gaussian pulse with a width of 8 ps compared to a Purcell-enhanced lifetime of 110 ps.
#
# In the code below, we use a small helper to shift both ``emitter/resonance`` and ``cavity/resonance`` together. That keeps the laser pulse fixed in its rotating frame while we sweep the QD-cavity system relative to it.

# %%
pulse = Pulse.gaussian(parameters={'width': 10 / np.sqrt(4 * np.log(2))}) # width in ps
source = Source.phonon_assisted(pulse=pulse,
                                purcell_factor=10,
                                regime=0.1,  # coupling regime parameter (lower is further into the weak coupling regime)
                                timescale=110,  # Purcell-enhanced decay timescale in ps
                                temperature=7,  # Temperature in Kelvin
                                material=Material.ingaas_quantum_dot())

# %%
source.beta(parameters=resonance_scan_parameters(1.0, {'emitter/area': 20 * np.pi}))
# Out:
# 0.0876474997663822

# %% [markdown]
# Now that we have made our source, we can begin to characterise it by performing some experiments. To get an idea of the region where phonon-assisted excitation can occur, we can perform a photo-luminescence excitation (PLE) experiment very similar to what we did to find two-photon excitation for the biexciton source (see ex_quantum_dots.ipynb). This involves sweeping the detuning between the excitation laser pulse and the source resonance while monitoring the emission intensity. Equivalently, it is simpler for the simulation to sweep the 'resonance' of the QD-cavity system in the opposite direction relative to a fixed laser frequency. This allows the simulation to remain in the rotating frame of the laser pulse and avoid having to simulate very fast oscillations.

# %%
detunings = np.linspace(-2, 2, 31)  # sweep from -2/ps detuning up until 2/ps detuning
areas = np.linspace(0, 15, 30)  # sweep pulse area from 0 to 15 units of pi
intensity = [[source.mu(parameters=resonance_scan_parameters(d, {'emitter/area': a * np.pi})) for d in detunings] for a in areas]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 detunings = np.linspace(-2, 2, 31)  # sweep  from -2/ps detuning up until 2/ps detuning
#       2 areas = np.linspace(0, 15, 30)  # sweep pulse area from 0 to 15 units of pi
# ----> 3 intensity = [[source.mu(parameters={'resonance': -d, 'area': a * np.pi}) for d in detunings] for a in areas]
#
# Cell In[3], line 3, in <listcomp>(.0)
#       1 detunings = np.linspace(-2, 2, 31)  # sweep  from -2/ps detuning up until 2/ps detuning
#       2 areas = np.linspace(0, 15, 30)  # sweep pulse area from 0 to 15 units of pi
# ----> 3 intensity = [[source.mu(parameters={'resonance': -d, 'area': a * np.pi}) for d in detunings] for a in areas]
#
# Cell In[3], line 3, in <listcomp>(.0)
#       1 detunings = np.linspace(-2, 2, 31)  # sweep  from -2/ps detuning up until 2/ps detuning
#       2 areas = np.linspace(0, 15, 30)  # sweep pulse area from 0 to 15 units of pi
# ----> 3 intensity = [[source.mu(parameters={'resonance': -d, 'area': a * np.pi}) for d in detunings] for a in areas]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/components/sources/base_source.py:69, in SourceComponent.mu(self, port, parameters, pseudo_limit)
#      61 """
#      62 Computes the average photon number of light from a port.
#      63 :param port: the source port or list of ports to compute the statistics for.
#    (...)
#      66 :return: the average photon number for the specified port.
#      67 """
#      68 self._make_processor()
# ---> 69 return self._quality_processor.mu(port, parameters, pseudo_limit)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/quality.py:99, in ProcessorQuality.mu(self, port, parameters, pseudo_limit)
#      97 name, port = self._name_to_port(port)
#      98 pseudo_limit = self._estimate_pseudo_limit(port, parameters) if pseudo_limit is None else pseudo_limit
# ---> 99 mu = estimate_average_photon_number(self.component, port=port, pseudo_limit=pseudo_limit,
#     100                                     parameters=parameters)
#     101 self._update_quality({'mu': mu}, name)
#     102 return mu
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/algorithms/photon_statistics.py:32, in estimate_average_photon_number(source, port, pseudo_limit, parameters)
#      30 p = ProcessorBase(make_masked_source(source, port))
#      31 p.add(0, PhysicalDetectorGate(resolution=1, efficiency=pseudo_limit, ignore_zero=True))
# ---> 32 p0 = p.generating_points(parameters=parameters)[0][0]
#      34 # Get the brightness, correct for lossy regime
#      35 return abs((1 - p0) / pseudo_limit)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/base_processor.py:229, in ProcessorBase.generating_points(self, parameters, basis, options)
#     227 def generating_points(self, parameters: dict = None,
#     228                       basis: List[Qobj] = None, options: Options = None):
# --> 229     self._simulate_grove(parameters=parameters, basis=basis, options=options)
#     230     return [tree.get_points() for tree in self._grove]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/base_processor.py:218, in ProcessorBase._simulate_grove(self, parameters, bin_list, basis, options, continue_simulation)
#     215     branch_order += grove.add_branches(t0, branches)
#     217 # build propagator
# --> 218 propagator = generator.build_propagator(t0, parameters=parameters, options=options)
#     220 # apply propagator to all trees in the grove
#     221 grove.propagate(propagator, t1)  # propagate to next stop time
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/virtual/generator.py:20, in Generator.build_propagator(self, t, parameters, options)
#      17 def build_propagator(self, t: float, parameters: dict = None, options: Options = None):
#      18     options = self.default_options if options is None else options
# ---> 20     quadruple = self.component.evaluate_quadruple(t, parameters)
#      21     hamiltonian = quadruple.hamiltonian
#      22     environment = quadruple.environment
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/cache.py:26, in DefaultCache.__call__.<locals>.wrapper(*args, **kwargs)
#      23     return self.cached_function(*args[:self.arg_num],
#      24                                 frozendict(parameters.default) if parameters else None)
#      25 else:
# ---> 26     return self.function(*args[:self.arg_num], parameters)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:320, in Component.evaluate_quadruple(self, t, parameters)
#     317 @DefaultCache(time_arg=True)
#     318 def evaluate_quadruple(self, t: float, parameters: Union[dict, frozendict] = None):
#     319     if self._elements:
# --> 320         return self._rule(self.gather_quadruples(t, parameters))
#     321     else:
#     322         return EvaluatedQuadruple()
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:326, in Component.gather_quadruples(self, t, parameters)
#     324 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
#     325     parameters = self.set_parameters(parameters)
# --> 326     quad_list = [[quad.match(self.permutations[i]) for quad in component.gather_quadruples(t, parameters)]
#     327                  for i, component in enumerate(self._elements)]
#     328     return list(chain(*quad_list))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:326, in <listcomp>(.0)
#     324 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
#     325     parameters = self.set_parameters(parameters)
# --> 326     quad_list = [[quad.match(self.permutations[i]) for quad in component.gather_quadruples(t, parameters)]
#     327                  for i, component in enumerate(self._elements)]
#     328     return list(chain(*quad_list))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:326, in Component.gather_quadruples(self, t, parameters)
#     324 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
#     325     parameters = self.set_parameters(parameters)
# --> 326     quad_list = [[quad.match(self.permutations[i]) for quad in component.gather_quadruples(t, parameters)]
#     327                  for i, component in enumerate(self._elements)]
#     328     return list(chain(*quad_list))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:326, in <listcomp>(.0)
#     324 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
#     325     parameters = self.set_parameters(parameters)
# --> 326     quad_list = [[quad.match(self.permutations[i]) for quad in component.gather_quadruples(t, parameters)]
#     327                  for i, component in enumerate(self._elements)]
#     328     return list(chain(*quad_list))
#
#     [... skipping similar frames: <listcomp> at line 326 (1 times), Component.gather_quadruples at line 326 (1 times)]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:326, in Component.gather_quadruples(self, t, parameters)
#     324 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
#     325     parameters = self.set_parameters(parameters)
# --> 326     quad_list = [[quad.match(self.permutations[i]) for quad in component.gather_quadruples(t, parameters)]
#     327                  for i, component in enumerate(self._elements)]
#     328     return list(chain(*quad_list))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:326, in <listcomp>(.0)
#     324 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
#     325     parameters = self.set_parameters(parameters)
# --> 326     quad_list = [[quad.match(self.permutations[i]) for quad in component.gather_quadruples(t, parameters)]
#     327                  for i, component in enumerate(self._elements)]
#     328     return list(chain(*quad_list))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/system/multibody.py:120, in MultiBodyEmitterBase.gather_quadruples(self, t, parameters)
#     119 def gather_quadruples(self, t: float, parameters: dict = None) -> List[EvaluatedQuadruple]:
# --> 120     return [self.evaluate_quadruple(t, parameters)]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/system/multibody.py:179, in MultiBodyEmitter.evaluate_quadruple(self, t, parameters)
#     178 def evaluate_quadruple(self, t: float, parameters: dict = None) -> EvaluatedQuadruple:
# --> 179     return super().evaluate_quadruple(t, parameters) + \
#     180         self.coupling.evaluate_quadruple(t, self.set_parameters(parameters)) + \
#     181         self.control.evaluate_quadruple(t, self.set_parameters(parameters))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/system/multibody.py:116, in MultiBodyEmitterBase.evaluate_quadruple(self, t, parameters)
#     114 def evaluate_quadruple(self, t: float, parameters: dict = None) -> EvaluatedQuadruple:
#     115     parameters = self.set_parameters(parameters)
# --> 116     return self._rule([system.evaluate_quadruple(t, parameters) for system in self._subsystems],
#     117                       EvaluatedQuadruple())
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/system/multibody.py:116, in <listcomp>(.0)
#     114 def evaluate_quadruple(self, t: float, parameters: dict = None) -> EvaluatedQuadruple:
#     115     parameters = self.set_parameters(parameters)
# --> 116     return self._rule([system.evaluate_quadruple(t, parameters) for system in self._subsystems],
#     117                       EvaluatedQuadruple())
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/cache.py:26, in DefaultCache.__call__.<locals>.wrapper(*args, **kwargs)
#      23     return self.cached_function(*args[:self.arg_num],
#      24                                 frozendict(parameters.default) if parameters else None)
#      25 else:
# ---> 26     return self.function(*args[:self.arg_num], parameters)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/system/quantum.py:66, in SystemCollection.evaluate_quadruple(self, t, parameters)
#      63 @DefaultCache(time_arg=True)
#      64 def evaluate_quadruple(self, t: float, parameters: dict = None) -> EvaluatedQuadruple:
#      65     parameters = self.set_parameters(parameters)
# ---> 66     return self._rule([system.evaluate_quadruple(t, parameters) for system in self._objects], EvaluatedQuadruple())
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/quadruple.py:66, in EvaluatedQuadruple.__add__(self, other)
#      64     return self
#      65 else:
# ---> 66     return EvaluatedQuadruple(hamiltonian=self.hamiltonian + other.hamiltonian,
#      67                               environment=self.environment + other.environment,
#      68                               transitions=self.transitions + other.transitions,
#      69                               scatterer=self.scatterer.concatenate(other.scatterer))
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/quadruple.py:34, in EvaluatedQuadruple.__init__(self, hamiltonian, environment, transitions, scatterer)
#      32 if not self.transitions:
#      33     if scatterer:
# ---> 34         self.transitions = [EvaluatedOperator(constant=Qobj(inpt=0))] * scatterer.dim
#      36 self.scatterer = EvaluatedOperator(constant=qeye(self.modes)) \
#      37     if scatterer is None else scatterer
#      39 assert self.modes == self.scatterer.dim, \
#      40     "Scattering matrices must have a dimension matching the number of modes"
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/qutip/qobj.py:336, in Qobj.__init__(self, inpt, dims, shape, type, isherm, copy, fast, superrep, isunitary)
#     329         self.superrep = 'super'
#     331 # While the obvious check would be != that would fail valid
#     332 # use cases such as enr_fock and other enr_ functions.
#     333 # This does leave open the possibility of data still being
#     334 # misused such as Qobj(complex[n**2][1], dims = [[n],[n]])
#     335 if (self._data.shape[0] > np.prod(np.hstack(self.dims[0])) or
# --> 336    self._data.shape[1] > np.prod(np.hstack(self.dims[1]))) and \
#     337    self.type != 'super':
#     339     raise ValueError(f"Qobj has smaller dims {self.dims} " +
#     340                      f"than underlying shape {self._data.shape}")
#     342 # clear type cache
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3100, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2979 @array_function_dispatch(_prod_dispatcher)
#    2980 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2981          initial=np._NoValue, where=np._NoValue):
#    2982     """
#    2983     Return the product of array elements over a given axis.
#    2984
#    (...)
#    3098     10
#    3099     """
# -> 3100     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3101                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()
plt.pcolormesh(detunings, areas, intensity, shading='gouraud')
plt.colorbar(ax=ax)
plt.xlabel("Laser detuning ($1/ps$)")
plt.ylabel("Pulse area ($\pi$)")
plt.show()

# %% [markdown]
# From this map, we can identify two main features. First, we can see that there is a clear oscillation between bright and dark emission while increasing the pulse area at zero detuning. This shows that the emitter is undergoing Rabi oscillations due to the coherent driving. The second feature is a broad underlying resonance at a higher excitation pulse area, and when the detuning is positive (above the emitter transition line). This second feature is phonon-assisted excitation. To explore these two features in more detail, we can choose two detunings: (1) resonance $\delta=0$ and (2) phonon-assisted $\delta=0.6$ while increasing the power in finer steps.

# %%
areas = np.linspace(0, 20, 200)
intensity_rf = [source.mu(parameters=resonance_scan_parameters(0, {'emitter/area': a * np.pi})) for a in areas]
intensity_la = [source.mu(parameters=resonance_scan_parameters(0.6, {'emitter/area': a * np.pi})) for a in areas]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 areas = np.linspace(0, 20, 200)
# ----> 2 intensity_rf = [source.mu(parameters={'resonance': 0, 'area': a * np.pi}) for a in areas]
#       3 intensity_la = [source.mu(parameters={'resonance': -2.2, 'area': a * np.pi,
#       4                                       'width': 3 / np.sqrt(4 * np.log(2))}) for a in areas]
#
# Cell In[3], line 2, in <listcomp>(.0)
#       1 areas = np.linspace(0, 20, 200)
# ----> 2 intensity_rf = [source.mu(parameters={'resonance': 0, 'area': a * np.pi}) for a in areas]
#       3 intensity_la = [source.mu(parameters={'resonance': -2.2, 'area': a * np.pi,
#       4                                       'width': 3 / np.sqrt(4 * np.log(2))}) for a in areas]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/components/sources/base_source.py:69, in SourceComponent.mu(self, port, parameters, pseudo_limit)
#      61 """
#      62 Computes the average photon number of light from a port.
#      63 :param port: the source port or list of ports to compute the statistics for.
#    (...)
#      66 :return: the average photon number for the specified port.
#      67 """
#      68 self._make_processor()
# ---> 69 return self._quality_processor.mu(port, parameters, pseudo_limit)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/quality.py:99, in ProcessorQuality.mu(self, port, parameters, pseudo_limit)
#      97 name, port = self._name_to_port(port)
#      98 pseudo_limit = self._estimate_pseudo_limit(port, parameters) if pseudo_limit is None else pseudo_limit
# ---> 99 mu = estimate_average_photon_number(self.component, port=port, pseudo_limit=pseudo_limit,
#     100                                     parameters=parameters)
#     101 self._update_quality({'mu': mu}, name)
#     102 return mu
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/algorithms/photon_statistics.py:32, in estimate_average_photon_number(source, port, pseudo_limit, parameters)
#      30 p = ProcessorBase(make_masked_source(source, port))
#      31 p.add(0, PhysicalDetectorGate(resolution=1, efficiency=pseudo_limit, ignore_zero=True))
# ---> 32 p0 = p.generating_points(parameters=parameters)[0][0]
#      34 # Get the brightness, correct for lossy regime
#      35 return abs((1 - p0) / pseudo_limit)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/base_processor.py:229, in ProcessorBase.generating_points(self, parameters, basis, options)
#     227 def generating_points(self, parameters: dict = None,
#     228                       basis: List[Qobj] = None, options: Options = None):
# --> 229     self._simulate_grove(parameters=parameters, basis=basis, options=options)
#     230     return [tree.get_points() for tree in self._grove]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/simulate/base_processor.py:218, in ProcessorBase._simulate_grove(self, parameters, bin_list, basis, options, continue_simulation)
#     215     branch_order += grove.add_branches(t0, branches)
#     217 # build propagator
# --> 218 propagator = generator.build_propagator(t0, parameters=parameters, options=options)
#     220 # apply propagator to all trees in the grove
#     221 grove.propagate(propagator, t1)  # propagate to next stop time
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/virtual/generator.py:20, in Generator.build_propagator(self, t, parameters, options)
#      17 def build_propagator(self, t: float, parameters: dict = None, options: Options = None):
#      18     options = self.default_options if options is None else options
# ---> 20     quadruple = self.component.evaluate_quadruple(t, parameters)
#      21     hamiltonian = quadruple.hamiltonian
#      22     environment = quadruple.environment
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/cache.py:26, in DefaultCache.__call__.<locals>.wrapper(*args, **kwargs)
#      23     return self.cached_function(*args[:self.arg_num],
#      24                                 frozendict(parameters.default) if parameters else None)
#      25 else:
# ---> 26     return self.function(*args[:self.arg_num], parameters)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/component.py:320, in Component.evaluate_quadruple(self, t, parameters)
#     317 @DefaultCache(time_arg=True)
#     318 def evaluate_quadruple(self, t: float, parameters: Union[dict, frozendict] = None):
#     319     if self._elements:
# --> 320         return self._rule(self.gather_quadruples(t, parameters))
#     321     else:
#     322         return EvaluatedQuadruple()
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/network/element.py:23, in ElementCollection.__init__.<locals>.<lambda>(objects, *args)
#      15 def __init__(self,
#      16              elements: Union[AElement, List[AElement]] = None,
#      17              parameters: dict = None,
#      18              name: str = None,
#      19              rule: callable = None,
#      20              types: list = None):
#      21     self._elements = []
#      22     super().__init__(operators=elements, parameters=parameters, name=name,
# ---> 23                      rule=lambda objects, *args: prod(objects) if rule is None else rule,
#      24                      types=[AElement] if types is None else types)
#      26     self._initial_state = None
#      27     self._initial_time = None
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/quadruple.py:92, in EvaluatedQuadruple.__mul__(self, other)
#      88 other_vector = [trn.tensor_insert(1, subdims) for trn in other.transitions]
#      90 hamiltonian = self.hamiltonian.tensor_insert(0, subdims) + other.hamiltonian.tensor_insert(1, subdims)
# ---> 92 environment = [env.tensor_insert(0, subdims) for env in self.environment] + \
#      93               [env.tensor_insert(1, subdims) for env in other.environment]
#      95 transitions = evop_mv(scatterer, self_vector)
#      96 transitions = [transitions[i] + other_vector[i] for i in range(0, len(transitions))]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/quadruple.py:92, in <listcomp>(.0)
#      88 other_vector = [trn.tensor_insert(1, subdims) for trn in other.transitions]
#      90 hamiltonian = self.hamiltonian.tensor_insert(0, subdims) + other.hamiltonian.tensor_insert(1, subdims)
# ---> 92 environment = [env.tensor_insert(0, subdims) for env in self.environment] + \
#      93               [env.tensor_insert(1, subdims) for env in other.environment]
#      95 transitions = evop_mv(scatterer, self_vector)
#      96 transitions = [transitions[i] + other_vector[i] for i in range(0, len(transitions))]
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/operator.py:242, in EvaluatedOperator.tensor_insert(self, i, dims)
#     238 def tensor_insert(self, i: int, dims: list):
#     239     return EvaluatedOperator(
#     240         constant=tensor_insert(self.constant, i, dims) if self.constant.isoper or self.constant.issuper
#     241         else self.constant,
# --> 242         variable=[v.tensor_insert(i, dims) for v in self.variable])
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/operator.py:242, in <listcomp>(.0)
#     238 def tensor_insert(self, i: int, dims: list):
#     239     return EvaluatedOperator(
#     240         constant=tensor_insert(self.constant, i, dims) if self.constant.isoper or self.constant.issuper
#     241         else self.constant,
# --> 242         variable=[v.tensor_insert(i, dims) for v in self.variable])
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/operator.py:172, in OpFuncPair.tensor_insert(self, i, dims)
#     171 def tensor_insert(self, i: int, dims: list):
# --> 172     return OpFuncPair(op=tensor_insert(self.op, i, dims), func=self.func)
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/zpgenerator/time/evaluate/tensor.py:20, in tensor_insert(op, n, dims)
#      18         if dims[i] != [1]:
#      19             opvec.append(spre(qeye(dims[i]))) if op.issuper else opvec.append(qeye(dims[i]))
# ---> 20 new_op = super_tensor(opvec) if op.issuper else tensor(opvec)
#      21 return new_op
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/qutip/tensor.py:130, in super_tensor(*args)
#     127 shuffled_tensor = tensor(shuffled_ops)
#     129 # Unshuffle and return.
# --> 130 out = reshuffle(shuffled_tensor)
#     131 out.superrep = args[0].superrep
#     132 return out
#
# File ~/PycharmProjects/emitter_task_force/venv/lib/python3.9/site-packages/qutip/permute.py:135, in reshuffle(q_oper)
#     126 n_subsystems = len(q_oper.dims[0][0])
#     128 # Generate a list of lists (lol) that represents the permutation order we
#     129 # need. It's easiest to do so if we make an array, then turn it into a lol
#     130 # by using map(list, ...). That array is generated by using reshape and
#     131 # transpose to turn an array like [a, b, a, b, ..., a, b] into one like
#     132 # [a, a, ..., a, b, b, ..., b].
#     133 perm_idxs = map(list,
#     134                 np.arange(n_subsystems * n_indices)[
# --> 135                     np.arange(n_subsystems * n_indices).reshape(
#     136                         (n_indices, n_subsystems)).T.flatten()
#     137                 ].reshape((n_subsystems, n_indices))
#     138                 )
#     140 return q_oper.permute(list(perm_idxs))
#
# KeyboardInterrupt:

# %%
plt.plot(areas, intensity_rf, label='Resonance excitation')
plt.plot(areas, intensity_la, label='Phonon-assisted excitation')
plt.ylabel("Average photon number emitted")
plt.xlabel("Pulse area ($\pi$)")
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
source.photon_statistics(parameters=resonance_scan_parameters(0.6, {'emitter/area': 20 * np.pi}))
# Out:
# Number  | Probability
# 0       | 0.99232
# 1       | 0.00767
# 2       | 0.00001
# 3       | 0.00000
# 4       | 0.00000
#
# Figure of Merit       | Value
# Brightness            | 0.0077
# Average photon number | 0.0077
# Intensity correlation | 0.2399
#
# Figure of Merit                | Value
# First order number coherence   | 0.0253
# Second order number coherence  | 0.1906
# Hong-Ou-Mandel visibility      | 0.7127
# Mean wavepacket overlap        | 0.9527

# %% [markdown]
# From this plot, it is easier to see that phonon-assisted excitation can achieve a comparable emission probability to resonance excitation. In this case, the ratio is:

# %%
max(intensity_la)/max(intensity_rf)
# Out:
# 0.8320533623565026

# %% [markdown]
# or 83% as high as bright as resonance excitation. This value is very similar to the 85% measured in the lab using slightly different system parameters [[S.E. Thomas et al., Phys. Rev. Lett. 126, 233601 (2021)](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.126.233601)].

# %% [markdown]
# ## 3. Lifetime

# %% [markdown]
# The emitter dressing, relaxation, and subsequent adiabatic undressing gives rise to a very particular-looking dynamic evolution of the emitter population. Let's take a look at what this population evolution looks like for the source we defined in the previous section.
#
# By default, the phonon-assisted source has the spontaneous emission port of the quantum dot masked so that only the cavity emission is collected for use in a circuit. This means that the spontaneous emission port is closed by default. Since we wish to monitor the lifetime of the quantum dot itself, in addition to our desired photon, we can open all closed ports after creating our source.

# %%
pulse = Pulse.gaussian(parameters={'width': 8}) # width in ps
source = Source.phonon_assisted(pulse=pulse,
                                purcell_factor=10,
                                regime=0.1,  # coupling regime parameter (lower is further into the weak coupling regime)
                                timescale=110,  # Purcell-enhanced decay timescale in ps
                                temperature=7,  # Temperature in Kelvin
                                material=Material.ingaas_quantum_dot())
source.output.open_all()

# %% [markdown]
# Now, when we wish to compute properties of the source, we must specify which port we are targeting. In this case, the unmasked source as spontaneous emission as port 0 and cavity emission as port 1. Knowing this, let's plot the lifetimes of both ports for a detuning of $\delta=0.6$ and pulse area of $\Theta = 20$, in addition to the pulse. To make things visually clear, we can scale the shapes appropriately using the 'scale' keyword. In this case, if we scale the QD population by the inverse of its decay rate, we get exactly the occupation probability of the emitter excited state.

# %%
parameters = resonance_scan_parameters(0.6, {'emitter/area': 20 * np.pi})
source.plot_lifetime(port=0, end=150, parameters=parameters, scale=1/source.default_parameters['emitter/decay'], label='QD Population')
source.plot_lifetime(port=1, end=150, parameters=parameters, label='Cavity wavepacket shape', scale=150)
p = pulse.plot(scale=6, label='Pulse magnitude')
p.xlabel('Time, t (ps)')
p.show()

# %% [markdown]
# From this plot, we can see that the QD population increases to about 1/2 at the peak of the Gaussian pulse. This indicates that the pulse has fully dressed the system and the phonon relaxation has begun to populate the lower-energy dressed eigenstate. As the pulse turns off, the higher and lower-energy eigenstates adiabatically return to their ground and excited states, respectively. This undressing pushes the QD population up into the excited state, as illustrated by the rising population as the pulse decays. Meanwhile, the cavity begins to produce light, as illustrated by the orange curve. During the pulse, there is a remnant emission occurring, which is actually undesired as it indicates that the system has relaxed to the ground state during the pulse, allow for possible re-excitation and subsequent multi-photon emission. However, the vast majority of the emission occurs as the pulse decays and the QD population is then accelerated through the cavity mode via the Purcell effect, leading to efficient single-photon emission.

# %% [markdown]
# ## 4. Photon statistics

# %% [markdown]
# Once we have set up our source, it is easy to check other characteristics, such as the amount of multi-photon emission. Let's take a look at the brightness (probability of emitting at least one photon) and intensity correlation for a $\pi$-pulse excitation compared to a $20\pi$-pulse excitation, both as a function of detuning. Recall that, in the previous section, we opened all ports of the source. To compute the photon statistics for emission from the cavity mode, we should specify port=1.

# %%
detunings = np.linspace(-3, 2, 200)
stats_pi = [source.photon_statistics(port=1, truncation=2, parameters=resonance_scan_parameters(d)) for d in detunings]
stats_20pi = [source.photon_statistics(port=1, truncation=2, parameters=resonance_scan_parameters(d, {'emitter/area': 20 * np.pi})) for d in detunings]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.semilogy(detunings, [ps.beta() for ps in stats_pi], label='$\theta$ = $\pi$')
ax1.semilogy(detunings, [ps.beta() for ps in stats_20pi], label='$\theta$ = 20 $\pi$')
ax1.legend()
ax1.set(xlabel='Detuning (1/ps)', ylabel='Brightness')

ax2.semilogy(detunings, [ps.g2() for ps in stats_pi], label='$\theta$ = $\pi$')
ax2.semilogy(detunings, [ps.g2() for ps in stats_20pi], label='$\theta$ = 20 $\pi$')
ax2.legend()
ax2.set(xlabel='Detuning (1/ps)', ylabel='Intensity correlation', ylim=[0.01, 2])
fig.tight_layout(pad=3.0)

# %% [markdown]
# In the left panel, we can identify the QD-cavity resonance (blue curve) around a zero detuning, corresponding to the resonance excitation condition. However, we can also identify the phonon sideband as a broad lower-intensity resonance. In this case, the curve looks stepped due to rounding after the statistics truncation. At higher excitation pulse area, we can see the phonon-assisted region at positive detuning, reaching nearly as high as the peak resonance excitation value. In the right panel, we can see a very interesting double-peak feature when driving the system with a $\pi$-pulse. The dip corresponds to the resonance excitation condition, while the side peaks actually correspond to detunings where the effective Rabi frequency performs an effective $2\pi$ pulse. This quick suppression in QD population coincides with a bunching effect, pushing the intensity correlation above that of a coherent state. On the other hand, at higher pulse area of $20\pi$, we see an even smaller multi-photon emission in the phonon-assisted regime.

# %% [markdown]
# ## 5. Custom pulse shapes

# %% [markdown]
# Due to the general scope of the ZPG backend, we are not restricted to pre-defined pulse shapes. Instead, we can supply our phonon-assisted source with a custom pulse shape constructed from interpolating functions and the Pulse.custom() class method.

# %%
from scipy.interpolate import interp1d

pulse_shape = interp1d([-20, -10, -5, 0, 5, 10, 20], [0, 0.2, 0.2, 0.1, 0.4, 0.2, 0], kind='quadratic')
pulse_phase = interp1d([-20, -10, -5, 0, 5, 10, 20], [0, -1, 1, 1, -1, 1, 1], kind='quadratic')

custom_pulse = Pulse.custom(shape=lambda t, args: args['area'] * abs(pulse_shape(t)) * np.exp(1.j * pulse_phase(t)),
                            gate = [-20, 20],  #  specify the time interval for the pulse (it will be 0 elsewhere)
                            parameters={'area': 20 * np.pi},  # specify any parameters used in the shape and their defaults
                            auto_normalise=True,  # automatically normalize the shape
                            norm=20 * np.pi)  # specify what the normalization should be for default parameters

source = Source.phonon_assisted(pulse=custom_pulse, parameters=resonance_scan_parameters(0.6),
                                purcell_factor=10, regime=0.1, timescale=110,
                                temperature=7, material=Material.ingaas_quantum_dot())
source.output.open_all()

# %%
source.plot_lifetime(port=0, end=100, scale=1/source.default_parameters['emitter/decay'], label='QD Population')
source.plot_lifetime(port=1, end=100, label='Photon shape', scale=150)
custom_pulse.plot(scale=1/10, label='Pulse magnitude')
custom_pulse.plot_phase(scale=1/50, label='Pulse phase', xlabel='Time, t (ps)').show()
